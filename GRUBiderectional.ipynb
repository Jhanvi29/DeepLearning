# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset
import gzip
import gensim.downloader as genapi
import sys
import pickle
import random
import gensim.downloader as genapi
from gensim.models import KeyedVectors 
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
import os
import matplotlib.pyplot as plt
import time
import copy

# %%
# !tar xvf text_datasets_for_DLStudio.tar.gz
# Out:
# data/
# data/sentiment_dataset_test_3.tar.gz
# data/sentiment_dataset_test_40.tar.gz
# data/sentiment_dataset_train_3.tar.gz
# data/sentiment_dataset_test_200.tar.gz
# data/sentiment_dataset_test_400.tar.gz
# data/sentiment_dataset_train_40.tar.gz
# data/sentiment_dataset_train_200.tar.gz
# data/sentiment_dataset_train_400.tar.gz

# %%
class SentimentAnalysisDataLoader(torch.utils.data.Dataset):
    def __init__(self, dataroot, train_or_test, dataset_file, path_to_saved_embeddings=None):
        super().__init__()
        import gensim.downloader as gen_api
#                self.word_vectors = gen_api.load("word2vec-google-news-300")
        self.path_to_saved_embeddings = path_to_saved_embeddings
        self.train_or_test = train_or_test
        root_dir = dataroot
        f = gzip.open(root_dir + dataset_file, 'rb')
        dataset = f.read()
        if path_to_saved_embeddings is not None:
            import gensim.downloader as genapi
            from gensim.models import KeyedVectors 
            if os.path.exists(path_to_saved_embeddings + 'vectors.kv'):
                self.word_vectors = KeyedVectors.load(path_to_saved_embeddings + 'vectors.kv')
            else:
                print("""\n\nSince this is your first time to install the word2vec embeddings, it may take"""
                      """\na couple of minutes. The embeddings occupy around 3.6GB of your disk space.\n\n""")
                self.word_vectors = genapi.load("word2vec-google-news-300")               
                ##  'kv' stands for  "KeyedVectors", a special datatype used by gensim because it 
                ##  has a smaller footprint than dict
                self.word_vectors.save(path_to_saved_embeddings + 'vectors.kv')    
        if train_or_test == 'train':
            if sys.version_info[0] == 3:
                self.positive_reviews_train, self.negative_reviews_train, self.vocab = pickle.loads(dataset, encoding='latin1')
            else:
                self.positive_reviews_train, self.negative_reviews_train, self.vocab = pickle.loads(dataset)
            self.categories = sorted(list(self.positive_reviews_train.keys()))
            self.category_sizes_train_pos = {category : len(self.positive_reviews_train[category]) for category in self.categories}
            self.category_sizes_train_neg = {category : len(self.negative_reviews_train[category]) for category in self.categories}
            self.indexed_dataset_train = []
            for category in self.positive_reviews_train:
                for review in self.positive_reviews_train[category]:
                    self.indexed_dataset_train.append([review, category, 1])
            for category in self.negative_reviews_train:
                for review in self.negative_reviews_train[category]:
                    self.indexed_dataset_train.append([review, category, 0])
            random.shuffle(self.indexed_dataset_train)
        elif train_or_test == 'test':
            if sys.version_info[0] == 3:
                self.positive_reviews_test, self.negative_reviews_test, self.vocab = pickle.loads(dataset, encoding='latin1')
            else:
                self.positive_reviews_test, self.negative_reviews_test, self.vocab = pickle.loads(dataset)
            self.vocab = sorted(self.vocab)
            self.categories = sorted(list(self.positive_reviews_test.keys()))
            self.category_sizes_test_pos = {category : len(self.positive_reviews_test[category]) for category in self.categories}
            self.category_sizes_test_neg = {category : len(self.negative_reviews_test[category]) for category in self.categories}
            self.indexed_dataset_test = []
            for category in self.positive_reviews_test:
                for review in self.positive_reviews_test[category]:
                    self.indexed_dataset_test.append([review, category, 1])
            for category in self.negative_reviews_test:
                for review in self.negative_reviews_test[category]:
                    self.indexed_dataset_test.append([review, category, 0])
            random.shuffle(self.indexed_dataset_test)

    def review_to_tensor(self, review):
        list_of_embeddings = []
        for i,word in enumerate(review):
            if word in self.word_vectors.key_to_index:
                embedding = self.word_vectors[word]
                list_of_embeddings.append(np.array(embedding))
            else:
                next
        review_tensor = torch.FloatTensor( list_of_embeddings )
        return review_tensor

    def sentiment_to_tensor(self, sentiment):
        sentiment_tensor = torch.zeros(2)
        if sentiment == 1:
            sentiment_tensor[1] = 1
        elif sentiment == 0: 
            sentiment_tensor[0] = 1
        sentiment_tensor = sentiment_tensor.type(torch.long)
        return sentiment_tensor

    def __len__(self):
        if self.train_or_test == 'train':
            return len(self.indexed_dataset_train)
        elif self.train_or_test == 'test':
            return len(self.indexed_dataset_test)

    def __getitem__(self, idx):
        sample = self.indexed_dataset_train[idx] if self.train_or_test == 'train' else self.indexed_dataset_test[idx]
        review = sample[0]
        review_category = sample[1]
        review_sentiment = sample[2]
        review_sentiment = self.sentiment_to_tensor(review_sentiment)
        review_tensor = self.review_to_tensor(review)
        category_index = self.categories.index(review_category)
        sample = {'review'       : review_tensor, 
                  'category'     : category_index, # should be converted to tensor, but not yet used
                  'sentiment'    : review_sentiment }
        return sample

# %%
dataroot = './'
dataset_archive_test = "data/sentiment_dataset_test_400.tar.gz"
path_to_saved_embeddings = './'
batch_size = 10
path_saved_model = './net.pth'


dataserver_test = SentimentAnalysisDataLoader(dataroot, train_or_test = 'test',dataset_file = dataset_archive_test,
                                 path_to_saved_embeddings = path_to_saved_embeddings)
test_dataloader = torch.utils.data.DataLoader(dataserver_test,batch_size=batch_size,shuffle=False, num_workers=2)

# %%
class GRUnetWithEmbeddings(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=1): 
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers , bidirectional = True)
        self.fc = nn.Linear(hidden_size*2, output_size)
        self.relu = nn.ReLU()
        self.logsoftmax = nn.LogSoftmax(dim=1)
        
    def forward(self, x, h):
        out, h = self.gru(x, h)
        #print(out.shape)
        #print(h.shape)
        out = self.fc(self.relu(out[:,-1]))
        out = self.logsoftmax(out)
        
        return out, h

    def init_hidden(self):
        weight = next(self.parameters()).data
        hidden = weight.new( 4, 1,  self.hidden_size ).zero_()
        return hidden

# %%
def run_code_for_training_for_text_classification_with_GRU_word2vec(net, display_train_loss, learning_rate): 
    filename_for_out = "performance_numbers_" + str(epochs) + ".txt"
    FILE = open(filename_for_out, 'w')
    net = copy.deepcopy(net)
    net = net.to(device)
    ##  Note that the GREnet now produces the LogSoftmax output:
    criterion = nn.NLLLoss()
    accum_times = []
    optimizer = optim.Adam(net.parameters(), lr=0.0005, betas=(0.5, 0.999))
    training_loss_tally = []
    start_time = time.perf_counter()
    for epoch in range(epochs):  
        print("")
        running_loss = 0.0
        for i, data in enumerate(train_dataloader):    
            review_tensor,category,sentiment = data['review'], data['category'], data['sentiment']
            review_tensor = review_tensor.to(device)
            sentiment = sentiment.to(device)
            ## The following type conversion needed for MSELoss:
            ##sentiment = sentiment.float()
            optimizer.zero_grad()
            hidden = net.init_hidden().to(device)
            for k in range(review_tensor.shape[1]):
                output, hidden = net(torch.unsqueeze(torch.unsqueeze(review_tensor[0,k],0),0), hidden)
            loss = criterion(output, torch.argmax(sentiment, 1))
            running_loss += loss.item()
            loss.backward()
            optimizer.step()
            if i % 200 == 199:    
                avg_loss = running_loss / float(200)
                training_loss_tally.append(avg_loss)
                current_time = time.perf_counter()
                time_elapsed = current_time-start_time
                print("[epoch:%d  iter:%4d  elapsed_time:%4d secs]     loss: %.5f" % (epoch+1,i+1, time_elapsed,avg_loss))
                accum_times.append(current_time-start_time)
                FILE.write("%.5f\n" % avg_loss)
                FILE.flush()
                running_loss = 0.0
    torch.save(net, 'net.pth')
    print("Total Training Time: {}".format(str(sum(accum_times))))
    print("\nFinished Training\n\n")
    if display_train_loss:
        plt.figure(figsize=(10,5))
        plt.title("Training Loss vs. Iterations")
        plt.plot(training_loss_tally)
        plt.xlabel("iterations")
        plt.ylabel("training loss")
        plt.legend()
        plt.savefig("training_loss.png")
        plt.show()

# %%
    dataroot = './'
    dataset_archive_train = "data/sentiment_dataset_train_400.tar.gz"
    path_to_saved_embeddings = './'
    momentum = 0.9
    learning_rate =  1e-3
    epochs = 5
    batch_size = 1
    classes = ('negative','positive')
    device = 'cuda'


    dataserver_train = SentimentAnalysisDataLoader(dataroot, train_or_test = 'train',dataset_file = dataset_archive_train,
                                 path_to_saved_embeddings = path_to_saved_embeddings)
    train_dataloader = torch.utils.data.DataLoader(dataserver_train,
                        batch_size=batch_size,shuffle=True, num_workers=0)
    
    model = GRUnetWithEmbeddings(input_size=300, hidden_size=300, output_size=2, num_layers=2)
    
    run_code_for_training_for_text_classification_with_GRU_word2vec(model, display_train_loss=True,learning_rate=learning_rate)
# Out:
# [epoch:1  iter: 200  elapsed_time:  17 secs]     loss: 0.69682
# [epoch:1  iter: 400  elapsed_time:  36 secs]     loss: 0.67510
# [epoch:1  iter: 600  elapsed_time:  54 secs]     loss: 0.66102
# [epoch:1  iter: 800  elapsed_time:  73 secs]     loss: 0.68487
# [epoch:1  iter:1000  elapsed_time:  91 secs]     loss: 0.62272
# [epoch:1  iter:1200  elapsed_time: 111 secs]     loss: 0.63797
# [epoch:1  iter:1400  elapsed_time: 127 secs]     loss: 0.64466
# [epoch:1  iter:1600  elapsed_time: 146 secs]     loss: 0.66140
# [epoch:1  iter:1800  elapsed_time: 163 secs]     loss: 0.71000
# [epoch:1  iter:2000  elapsed_time: 180 secs]     loss: 0.68685
# [epoch:1  iter:2200  elapsed_time: 198 secs]     loss: 0.58416
# [epoch:1  iter:2400  elapsed_time: 217 secs]     loss: 0.55019
# [epoch:1  iter:2600  elapsed_time: 234 secs]     loss: 0.58293
# [epoch:1  iter:2800  elapsed_time: 252 secs]     loss: 0.56776
# [epoch:1  iter:3000  elapsed_time: 272 secs]     loss: 0.50800
# [epoch:1  iter:3200  elapsed_time: 289 secs]     loss: 0.48925
# [epoch:1  iter:3400  elapsed_time: 310 secs]     loss: 0.45837
# [epoch:1  iter:3600  elapsed_time: 326 secs]     loss: 0.47156
# [epoch:1  iter:3800  elapsed_time: 343 secs]     loss: 0.44296
# [epoch:1  iter:4000  elapsed_time: 360 secs]     loss: 0.53298
# [epoch:1  iter:4200  elapsed_time: 382 secs]     loss: 0.49549
# [epoch:1  iter:4400  elapsed_time: 398 secs]     loss: 0.48560
# [epoch:1  iter:4600  elapsed_time: 420 secs]     loss: 0.50012
# [epoch:1  iter:4800  elapsed_time: 438 secs]     loss: 0.37245
# [epoch:1  iter:5000  elapsed_time: 458 secs]     loss: 0.48505
# [epoch:1  iter:5200  elapsed_time: 475 secs]     loss: 0.41558
# [epoch:1  iter:5400  elapsed_time: 496 secs]     loss: 0.48412
# [epoch:1  iter:5600  elapsed_time: 516 secs]     loss: 0.43087
# [epoch:1  iter:5800  elapsed_time: 535 secs]     loss: 0.52767
# [epoch:1  iter:6000  elapsed_time: 552 secs]     loss: 0.36225
# [epoch:1  iter:6200  elapsed_time: 573 secs]     loss: 0.42303
# [epoch:1  iter:6400  elapsed_time: 591 secs]     loss: 0.42820
# [epoch:1  iter:6600  elapsed_time: 612 secs]     loss: 0.38162
# [epoch:1  iter:6800  elapsed_time: 631 secs]     loss: 0.38983
# [epoch:1  iter:7000  elapsed_time: 651 secs]     loss: 0.51103
# [epoch:1  iter:7200  elapsed_time: 670 secs]     loss: 0.36859
# [epoch:1  iter:7400  elapsed_time: 689 secs]     loss: 0.46391
# [epoch:1  iter:7600  elapsed_time: 710 secs]     loss: 0.42654
# [epoch:1  iter:7800  elapsed_time: 727 secs]     loss: 0.45559
# [epoch:1  iter:8000  elapsed_time: 749 secs]     loss: 0.35921
# [epoch:1  iter:8200  elapsed_time: 765 secs]     loss: 0.44987
# [epoch:1  iter:8400  elapsed_time: 785 secs]     loss: 0.43914
# [epoch:1  iter:8600  elapsed_time: 804 secs]     loss: 0.45225
# [epoch:1  iter:8800  elapsed_time: 824 secs]     loss: 0.42581
# [epoch:1  iter:9000  elapsed_time: 843 secs]     loss: 0.41909
# [epoch:1  iter:9200  elapsed_time: 863 secs]     loss: 0.39400
# [epoch:1  iter:9400  elapsed_time: 882 secs]     loss: 0.41533
# [epoch:1  iter:9600  elapsed_time: 898 secs]     loss: 0.36189
# [epoch:1  iter:9800  elapsed_time: 919 secs]     loss: 0.39208
# [epoch:1  iter:10000  elapsed_time: 938 secs]     loss: 0.35092
# [epoch:1  iter:10200  elapsed_time: 954 secs]     loss: 0.38034
# [epoch:1  iter:10400  elapsed_time: 973 secs]     loss: 0.36362
# [epoch:1  iter:10600  elapsed_time: 992 secs]     loss: 0.38549
# [epoch:1  iter:10800  elapsed_time:1011 secs]     loss: 0.38282
# [epoch:1  iter:11000  elapsed_time:1032 secs]     loss: 0.42840
# [epoch:1  iter:11200  elapsed_time:1054 secs]     loss: 0.38006
# [epoch:1  iter:11400  elapsed_time:1072 secs]     loss: 0.35622
# [epoch:1  iter:11600  elapsed_time:1092 secs]     loss: 0.35776
# [epoch:1  iter:11800  elapsed_time:1112 secs]     loss: 0.37431
# [epoch:1  iter:12000  elapsed_time:1132 secs]     loss: 0.44643
# [epoch:1  iter:12200  elapsed_time:1152 secs]     loss: 0.40383
# [epoch:1  iter:12400  elapsed_time:1173 secs]     loss: 0.37322
# [epoch:1  iter:12600  elapsed_time:1191 secs]     loss: 0.37538
# [epoch:1  iter:12800  elapsed_time:1212 secs]     loss: 0.39675
# [epoch:1  iter:13000  elapsed_time:1228 secs]     loss: 0.33143
# [epoch:1  iter:13200  elapsed_time:1246 secs]     loss: 0.33173
# [epoch:1  iter:13400  elapsed_time:1265 secs]     loss: 0.33656
# [epoch:1  iter:13600  elapsed_time:1285 secs]     loss: 0.40928
# [epoch:1  iter:13800  elapsed_time:1303 secs]     loss: 0.34439
# [epoch:1  iter:14000  elapsed_time:1324 secs]     loss: 0.40397
# [epoch:1  iter:14200  elapsed_time:1344 secs]     loss: 0.43644
#
# [epoch:2  iter: 200  elapsed_time:1366 secs]     loss: 0.35853
# [epoch:2  iter: 400  elapsed_time:1383 secs]     loss: 0.34253
# [epoch:2  iter: 600  elapsed_time:1402 secs]     loss: 0.32687
# [epoch:2  iter: 800  elapsed_time:1420 secs]     loss: 0.39650
# [epoch:2  iter:1000  elapsed_time:1441 secs]     loss: 0.36032
# [epoch:2  iter:1200  elapsed_time:1462 secs]     loss: 0.35445
# [epoch:2  iter:1400  elapsed_time:1480 secs]     loss: 0.36351
# [epoch:2  iter:1600  elapsed_time:1498 secs]     loss: 0.26871
# [epoch:2  iter:1800  elapsed_time:1519 secs]     loss: 0.33704
# [epoch:2  iter:2000  elapsed_time:1538 secs]     loss: 0.34221
# [epoch:2  iter:2200  elapsed_time:1555 secs]     loss: 0.32297
# [epoch:2  iter:2400  elapsed_time:1572 secs]     loss: 0.21560
# [epoch:2  iter:2600  elapsed_time:1594 secs]     loss: 0.33911
# [epoch:2  iter:2800  elapsed_time:1615 secs]     loss: 0.32125
# [epoch:2  iter:3000  elapsed_time:1634 secs]     loss: 0.35947
# [epoch:2  iter:3200  elapsed_time:1651 secs]     loss: 0.32631
# [epoch:2  iter:3400  elapsed_time:1669 secs]     loss: 0.29798
# [epoch:2  iter:3600  elapsed_time:1688 secs]     loss: 0.27536
# [epoch:2  iter:3800  elapsed_time:1707 secs]     loss: 0.28893
# [epoch:2  iter:4000  elapsed_time:1726 secs]     loss: 0.31819
# [epoch:2  iter:4200  elapsed_time:1746 secs]     loss: 0.34682
# [epoch:2  iter:4400  elapsed_time:1768 secs]     loss: 0.31376
# [epoch:2  iter:4600  elapsed_time:1787 secs]     loss: 0.31920
# [epoch:2  iter:4800  elapsed_time:1805 secs]     loss: 0.36819
# [epoch:2  iter:5000  elapsed_time:1823 secs]     loss: 0.32890
# [epoch:2  iter:5200  elapsed_time:1842 secs]     loss: 0.35831
# [epoch:2  iter:5400  elapsed_time:1860 secs]     loss: 0.37307
# [epoch:2  iter:5600  elapsed_time:1878 secs]     loss: 0.35811
# [epoch:2  iter:5800  elapsed_time:1896 secs]     loss: 0.33506
# [epoch:2  iter:6000  elapsed_time:1914 secs]     loss: 0.32742
# [epoch:2  iter:6200  elapsed_time:1932 secs]     loss: 0.27671
# [epoch:2  iter:6400  elapsed_time:1950 secs]     loss: 0.33224
# [epoch:2  iter:6600  elapsed_time:1970 secs]     loss: 0.35761
# [epoch:2  iter:6800  elapsed_time:1988 secs]     loss: 0.28016
# [epoch:2  iter:7000  elapsed_time:2007 secs]     loss: 0.41844
# [epoch:2  iter:7200  elapsed_time:2027 secs]     loss: 0.42352
# [epoch:2  iter:7400  elapsed_time:2044 secs]     loss: 0.26495
# [epoch:2  iter:7600  elapsed_time:2063 secs]     loss: 0.29497
# [epoch:2  iter:7800  elapsed_time:2082 secs]     loss: 0.31413
# [epoch:2  iter:8000  elapsed_time:2102 secs]     loss: 0.33529
# [epoch:2  iter:8200  elapsed_time:2123 secs]     loss: 0.31429
# [epoch:2  iter:8400  elapsed_time:2140 secs]     loss: 0.33211
# [epoch:2  iter:8600  elapsed_time:2159 secs]     loss: 0.27031
# [epoch:2  iter:8800  elapsed_time:2180 secs]     loss: 0.30245
# [epoch:2  iter:9000  elapsed_time:2199 secs]     loss: 0.31107
# [epoch:2  iter:9200  elapsed_time:2218 secs]     loss: 0.25191
# [epoch:2  iter:9400  elapsed_time:2237 secs]     loss: 0.34481
# [epoch:2  iter:9600  elapsed_time:2257 secs]     loss: 0.31826
# [epoch:2  iter:9800  elapsed_time:2274 secs]     loss: 0.27961
# [epoch:2  iter:10000  elapsed_time:2294 secs]     loss: 0.31053
# [epoch:2  iter:10200  elapsed_time:2310 secs]     loss: 0.30434
# [epoch:2  iter:10400  elapsed_time:2329 secs]     loss: 0.40474
# [epoch:2  iter:10600  elapsed_time:2347 secs]     loss: 0.32189
# [epoch:2  iter:10800  elapsed_time:2363 secs]     loss: 0.42693
# [epoch:2  iter:11000  elapsed_time:2382 secs]     loss: 0.32637
# [epoch:2  iter:11200  elapsed_time:2400 secs]     loss: 0.34968
# [epoch:2  iter:11400  elapsed_time:2422 secs]     loss: 0.28146
# [epoch:2  iter:11600  elapsed_time:2438 secs]     loss: 0.33869
# [epoch:2  iter:11800  elapsed_time:2457 secs]     loss: 0.35257
# [epoch:2  iter:12000  elapsed_time:2475 secs]     loss: 0.43604
# [epoch:2  iter:12200  elapsed_time:2496 secs]     loss: 0.33953
# [epoch:2  iter:12400  elapsed_time:2515 secs]     loss: 0.27077
# [epoch:2  iter:12600  elapsed_time:2532 secs]     loss: 0.32715
# [epoch:2  iter:12800  elapsed_time:2553 secs]     loss: 0.34803
# [epoch:2  iter:13000  elapsed_time:2573 secs]     loss: 0.28789
# [epoch:2  iter:13200  elapsed_time:2593 secs]     loss: 0.28698
# [epoch:2  iter:13400  elapsed_time:2611 secs]     loss: 0.39542
# [epoch:2  iter:13600  elapsed_time:2631 secs]     loss: 0.35077
# [epoch:2  iter:13800  elapsed_time:2648 secs]     loss: 0.28337
# [epoch:2  iter:14000  elapsed_time:2668 secs]     loss: 0.33311
# [epoch:2  iter:14200  elapsed_time:2688 secs]     loss: 0.20128
#
# [epoch:3  iter: 200  elapsed_time:2711 secs]     loss: 0.25922
# [epoch:3  iter: 400  elapsed_time:2732 secs]     loss: 0.31930
# [epoch:3  iter: 600  elapsed_time:2750 secs]     loss: 0.29208
# [epoch:3  iter: 800  elapsed_time:2768 secs]     loss: 0.28004
# [epoch:3  iter:1000  elapsed_time:2786 secs]     loss: 0.25616
# [epoch:3  iter:1200  elapsed_time:2804 secs]     loss: 0.27410
# [epoch:3  iter:1400  elapsed_time:2825 secs]     loss: 0.22415
# [epoch:3  iter:1600  elapsed_time:2844 secs]     loss: 0.27080
# [epoch:3  iter:1800  elapsed_time:2864 secs]     loss: 0.26931
# [epoch:3  iter:2000  elapsed_time:2881 secs]     loss: 0.25468
# [epoch:3  iter:2200  elapsed_time:2901 secs]     loss: 0.21308
# [epoch:3  iter:2400  elapsed_time:2920 secs]     loss: 0.26266
# [epoch:3  iter:2600  elapsed_time:2939 secs]     loss: 0.28977
# [epoch:3  iter:2800  elapsed_time:2958 secs]     loss: 0.25915
# [epoch:3  iter:3000  elapsed_time:2974 secs]     loss: 0.26305
# [epoch:3  iter:3200  elapsed_time:2992 secs]     loss: 0.21016
# [epoch:3  iter:3400  elapsed_time:3008 secs]     loss: 0.34505
# [epoch:3  iter:3600  elapsed_time:3028 secs]     loss: 0.22705
# [epoch:3  iter:3800  elapsed_time:3048 secs]     loss: 0.23428
# [epoch:3  iter:4000  elapsed_time:3069 secs]     loss: 0.30770
# [epoch:3  iter:4200  elapsed_time:3087 secs]     loss: 0.24262
# [epoch:3  iter:4400  elapsed_time:3108 secs]     loss: 0.24161
# [epoch:3  iter:4600  elapsed_time:3124 secs]     loss: 0.23386
# [epoch:3  iter:4800  elapsed_time:3144 secs]     loss: 0.29205
# [epoch:3  iter:5000  elapsed_time:3163 secs]     loss: 0.35474
# [epoch:3  iter:5200  elapsed_time:3180 secs]     loss: 0.23773
# [epoch:3  iter:5400  elapsed_time:3201 secs]     loss: 0.23880
# [epoch:3  iter:5600  elapsed_time:3221 secs]     loss: 0.33034
# [epoch:3  iter:5800  elapsed_time:3240 secs]     loss: 0.26513
# [epoch:3  iter:6000  elapsed_time:3260 secs]     loss: 0.24785
# [epoch:3  iter:6200  elapsed_time:3278 secs]     loss: 0.23158
# [epoch:3  iter:6400  elapsed_time:3296 secs]     loss: 0.28808
# [epoch:3  iter:6600  elapsed_time:3314 secs]     loss: 0.19095
# [epoch:3  iter:6800  elapsed_time:3335 secs]     loss: 0.26621
# [epoch:3  iter:7000  elapsed_time:3354 secs]     loss: 0.18567
# [epoch:3  iter:7200  elapsed_time:3373 secs]     loss: 0.32744
# [epoch:3  iter:7400  elapsed_time:3391 secs]     loss: 0.28723
# [epoch:3  iter:7600  elapsed_time:3407 secs]     loss: 0.27929
# [epoch:3  iter:7800  elapsed_time:3427 secs]     loss: 0.31097
# [epoch:3  iter:8000  elapsed_time:3446 secs]     loss: 0.31943
# [epoch:3  iter:8200  elapsed_time:3465 secs]     loss: 0.25526
# [epoch:3  iter:8400  elapsed_time:3483 secs]     loss: 0.23483
# [epoch:3  iter:8600  elapsed_time:3503 secs]     loss: 0.30212
# [epoch:3  iter:8800  elapsed_time:3523 secs]     loss: 0.32454
# [epoch:3  iter:9000  elapsed_time:3543 secs]     loss: 0.21737
# [epoch:3  iter:9200  elapsed_time:3562 secs]     loss: 0.25782
# [epoch:3  iter:9400  elapsed_time:3581 secs]     loss: 0.26333
# [epoch:3  iter:9600  elapsed_time:3599 secs]     loss: 0.25294
# [epoch:3  iter:9800  elapsed_time:3619 secs]     loss: 0.32076
# [epoch:3  iter:10000  elapsed_time:3638 secs]     loss: 0.26917
# [epoch:3  iter:10200  elapsed_time:3655 secs]     loss: 0.21656
# [epoch:3  iter:10400  elapsed_time:3676 secs]     loss: 0.30331
# [epoch:3  iter:10600  elapsed_time:3695 secs]     loss: 0.29794
# [epoch:3  iter:10800  elapsed_time:3714 secs]     loss: 0.26529
# [epoch:3  iter:11000  elapsed_time:3735 secs]     loss: 0.33632
# [epoch:3  iter:11200  elapsed_time:3752 secs]     loss: 0.24605
# [epoch:3  iter:11400  elapsed_time:3771 secs]     loss: 0.26039
# [epoch:3  iter:11600  elapsed_time:3790 secs]     loss: 0.23209
# [epoch:3  iter:11800  elapsed_time:3808 secs]     loss: 0.20577
# [epoch:3  iter:12000  elapsed_time:3826 secs]     loss: 0.27225
# [epoch:3  iter:12200  elapsed_time:3843 secs]     loss: 0.27348
# [epoch:3  iter:12400  elapsed_time:3864 secs]     loss: 0.29354
# [epoch:3  iter:12600  elapsed_time:3884 secs]     loss: 0.22833
# [epoch:3  iter:12800  elapsed_time:3901 secs]     loss: 0.27241
# [epoch:3  iter:13000  elapsed_time:3921 secs]     loss: 0.28874
# [epoch:3  iter:13200  elapsed_time:3940 secs]     loss: 0.19037
# [epoch:3  iter:13400  elapsed_time:3961 secs]     loss: 0.29863
# [epoch:3  iter:13600  elapsed_time:3980 secs]     loss: 0.36137
# [epoch:3  iter:13800  elapsed_time:3998 secs]     loss: 0.28780
# [epoch:3  iter:14000  elapsed_time:4016 secs]     loss: 0.20210
# [epoch:3  iter:14200  elapsed_time:4037 secs]     loss: 0.20331
#
# [epoch:4  iter: 200  elapsed_time:4058 secs]     loss: 0.19729
# [epoch:4  iter: 400  elapsed_time:4078 secs]     loss: 0.18540
# [epoch:4  iter: 600  elapsed_time:4099 secs]     loss: 0.18919
# [epoch:4  iter: 800  elapsed_time:4119 secs]     loss: 0.15121
# [epoch:4  iter:1000  elapsed_time:4138 secs]     loss: 0.13483
# [epoch:4  iter:1200  elapsed_time:4157 secs]     loss: 0.21098
# [epoch:4  iter:1400  elapsed_time:4174 secs]     loss: 0.22936
# [epoch:4  iter:1600  elapsed_time:4194 secs]     loss: 0.17410
# [epoch:4  iter:1800  elapsed_time:4214 secs]     loss: 0.14861
# [epoch:4  iter:2000  elapsed_time:4232 secs]     loss: 0.14047
# [epoch:4  iter:2200  elapsed_time:4251 secs]     loss: 0.20447
# [epoch:4  iter:2400  elapsed_time:4272 secs]     loss: 0.21119
# [epoch:4  iter:2600  elapsed_time:4290 secs]     loss: 0.17473
# [epoch:4  iter:2800  elapsed_time:4309 secs]     loss: 0.14295
# [epoch:4  iter:3000  elapsed_time:4325 secs]     loss: 0.09745
# [epoch:4  iter:3200  elapsed_time:4341 secs]     loss: 0.22441
# [epoch:4  iter:3400  elapsed_time:4359 secs]     loss: 0.21025
# [epoch:4  iter:3600  elapsed_time:4377 secs]     loss: 0.23263
# [epoch:4  iter:3800  elapsed_time:4395 secs]     loss: 0.17420
# [epoch:4  iter:4000  elapsed_time:4414 secs]     loss: 0.15236
# [epoch:4  iter:4200  elapsed_time:4433 secs]     loss: 0.17306
# [epoch:4  iter:4400  elapsed_time:4453 secs]     loss: 0.14280
# [epoch:4  iter:4600  elapsed_time:4470 secs]     loss: 0.24467
# [epoch:4  iter:4800  elapsed_time:4488 secs]     loss: 0.29417
# [epoch:4  iter:5000  elapsed_time:4505 secs]     loss: 0.16931
# [epoch:4  iter:5200  elapsed_time:4525 secs]     loss: 0.22500
# [epoch:4  iter:5400  elapsed_time:4544 secs]     loss: 0.16312
# [epoch:4  iter:5600  elapsed_time:4561 secs]     loss: 0.21676
# [epoch:4  iter:5800  elapsed_time:4581 secs]     loss: 0.22116
# [epoch:4  iter:6000  elapsed_time:4600 secs]     loss: 0.21303
# [epoch:4  iter:6200  elapsed_time:4619 secs]     loss: 0.15840
# [epoch:4  iter:6400  elapsed_time:4640 secs]     loss: 0.22876
# [epoch:4  iter:6600  elapsed_time:4659 secs]     loss: 0.16299
# [epoch:4  iter:6800  elapsed_time:4679 secs]     loss: 0.20167
# [epoch:4  iter:7000  elapsed_time:4700 secs]     loss: 0.16122
# [epoch:4  iter:7200  elapsed_time:4721 secs]     loss: 0.21363
# [epoch:4  iter:7400  elapsed_time:4737 secs]     loss: 0.22401
# [epoch:4  iter:7600  elapsed_time:4755 secs]     loss: 0.22142
# [epoch:4  iter:7800  elapsed_time:4774 secs]     loss: 0.21297
# [epoch:4  iter:8000  elapsed_time:4793 secs]     loss: 0.22296
# [epoch:4  iter:8200  elapsed_time:4814 secs]     loss: 0.20032
# [epoch:4  iter:8400  elapsed_time:4835 secs]     loss: 0.17055
# [epoch:4  iter:8600  elapsed_time:4853 secs]     loss: 0.22267
# [epoch:4  iter:8800  elapsed_time:4872 secs]     loss: 0.13457
# [epoch:4  iter:9000  elapsed_time:4892 secs]     loss: 0.18786
# [epoch:4  iter:9200  elapsed_time:4910 secs]     loss: 0.16817
# [epoch:4  iter:9400  elapsed_time:4931 secs]     loss: 0.21286
# [epoch:4  iter:9600  elapsed_time:4950 secs]     loss: 0.21004
# [epoch:4  iter:9800  elapsed_time:4971 secs]     loss: 0.12917
# [epoch:4  iter:10000  elapsed_time:4989 secs]     loss: 0.15404
# [epoch:4  iter:10200  elapsed_time:5009 secs]     loss: 0.23931
# [epoch:4  iter:10400  elapsed_time:5027 secs]     loss: 0.25973
# [epoch:4  iter:10600  elapsed_time:5046 secs]     loss: 0.18424
# [epoch:4  iter:10800  elapsed_time:5066 secs]     loss: 0.34332
# [epoch:4  iter:11000  elapsed_time:5086 secs]     loss: 0.17031
# [epoch:4  iter:11200  elapsed_time:5107 secs]     loss: 0.18277
# [epoch:4  iter:11400  elapsed_time:5125 secs]     loss: 0.23060
# [epoch:4  iter:11600  elapsed_time:5145 secs]     loss: 0.27092
# [epoch:4  iter:11800  elapsed_time:5165 secs]     loss: 0.23290
# [epoch:4  iter:12000  elapsed_time:5183 secs]     loss: 0.22080
# [epoch:4  iter:12200  elapsed_time:5200 secs]     loss: 0.17379
# [epoch:4  iter:12400  elapsed_time:5218 secs]     loss: 0.14596
# [epoch:4  iter:12600  elapsed_time:5236 secs]     loss: 0.22915
# [epoch:4  iter:12800  elapsed_time:5256 secs]     loss: 0.16539
# [epoch:4  iter:13000  elapsed_time:5273 secs]     loss: 0.22626
# [epoch:4  iter:13200  elapsed_time:5293 secs]     loss: 0.20076
# [epoch:4  iter:13400  elapsed_time:5311 secs]     loss: 0.19297
# [epoch:4  iter:13600  elapsed_time:5330 secs]     loss: 0.15593
# [epoch:4  iter:13800  elapsed_time:5348 secs]     loss: 0.22679
# [epoch:4  iter:14000  elapsed_time:5369 secs]     loss: 0.20876
# [epoch:4  iter:14200  elapsed_time:5386 secs]     loss: 0.23660
#
# [epoch:5  iter: 200  elapsed_time:5407 secs]     loss: 0.15525
# [epoch:5  iter: 400  elapsed_time:5429 secs]     loss: 0.12282
# [epoch:5  iter: 600  elapsed_time:5447 secs]     loss: 0.08783
# [epoch:5  iter: 800  elapsed_time:5467 secs]     loss: 0.18295
# [epoch:5  iter:1000  elapsed_time:5486 secs]     loss: 0.13029
# [epoch:5  iter:1200  elapsed_time:5509 secs]     loss: 0.13650
# [epoch:5  iter:1400  elapsed_time:5529 secs]     loss: 0.13812
# [epoch:5  iter:1600  elapsed_time:5546 secs]     loss: 0.09024
# [epoch:5  iter:1800  elapsed_time:5565 secs]     loss: 0.09390
# [epoch:5  iter:2000  elapsed_time:5584 secs]     loss: 0.07490
# [epoch:5  iter:2200  elapsed_time:5601 secs]     loss: 0.12078
# [epoch:5  iter:2400  elapsed_time:5619 secs]     loss: 0.09816
# [epoch:5  iter:2600  elapsed_time:5637 secs]     loss: 0.10498
# [epoch:5  iter:2800  elapsed_time:5656 secs]     loss: 0.11953
# [epoch:5  iter:3000  elapsed_time:5674 secs]     loss: 0.09733
# [epoch:5  iter:3200  elapsed_time:5693 secs]     loss: 0.10102
# [epoch:5  iter:3400  elapsed_time:5712 secs]     loss: 0.12719
# [epoch:5  iter:3600  elapsed_time:5731 secs]     loss: 0.14450
# [epoch:5  iter:3800  elapsed_time:5749 secs]     loss: 0.17215
# [epoch:5  iter:4000  elapsed_time:5769 secs]     loss: 0.10463
# [epoch:5  iter:4200  elapsed_time:5788 secs]     loss: 0.09969
# [epoch:5  iter:4400  elapsed_time:5806 secs]     loss: 0.16019
# [epoch:5  iter:4600  elapsed_time:5824 secs]     loss: 0.06111
# [epoch:5  iter:4800  elapsed_time:5843 secs]     loss: 0.18551
# [epoch:5  iter:5000  elapsed_time:5862 secs]     loss: 0.14974
# [epoch:5  iter:5200  elapsed_time:5881 secs]     loss: 0.23521
# [epoch:5  iter:5400  elapsed_time:5903 secs]     loss: 0.08857
# [epoch:5  iter:5600  elapsed_time:5921 secs]     loss: 0.15587
# [epoch:5  iter:5800  elapsed_time:5941 secs]     loss: 0.20917
# [epoch:5  iter:6000  elapsed_time:5959 secs]     loss: 0.11757
# [epoch:5  iter:6200  elapsed_time:5976 secs]     loss: 0.11899
# [epoch:5  iter:6400  elapsed_time:5996 secs]     loss: 0.17868
# [epoch:5  iter:6600  elapsed_time:6015 secs]     loss: 0.14268
# [epoch:5  iter:6800  elapsed_time:6034 secs]     loss: 0.11665
# [epoch:5  iter:7000  elapsed_time:6053 secs]     loss: 0.19353
# [epoch:5  iter:7200  elapsed_time:6073 secs]     loss: 0.16155
# [epoch:5  iter:7400  elapsed_time:6091 secs]     loss: 0.13558
# [epoch:5  iter:7600  elapsed_time:6108 secs]     loss: 0.17798
# [epoch:5  iter:7800  elapsed_time:6128 secs]     loss: 0.19317
# [epoch:5  iter:8000  elapsed_time:6149 secs]     loss: 0.12051
# [epoch:5  iter:8200  elapsed_time:6169 secs]     loss: 0.08570
# [epoch:5  iter:8400  elapsed_time:6190 secs]     loss: 0.10433
# [epoch:5  iter:8600  elapsed_time:6207 secs]     loss: 0.10338
# [epoch:5  iter:8800  elapsed_time:6222 secs]     loss: 0.07201
# [epoch:5  iter:9000  elapsed_time:6243 secs]     loss: 0.27029
# [epoch:5  iter:9200  elapsed_time:6264 secs]     loss: 0.10089
# [epoch:5  iter:9400  elapsed_time:6281 secs]     loss: 0.10191
# [epoch:5  iter:9600  elapsed_time:6299 secs]     loss: 0.10143
# [epoch:5  iter:9800  elapsed_time:6317 secs]     loss: 0.07059
# [epoch:5  iter:10000  elapsed_time:6334 secs]     loss: 0.18384
# [epoch:5  iter:10200  elapsed_time:6353 secs]     loss: 0.12035
# [epoch:5  iter:10400  elapsed_time:6373 secs]     loss: 0.09211
# [epoch:5  iter:10600  elapsed_time:6394 secs]     loss: 0.12660
# [epoch:5  iter:10800  elapsed_time:6415 secs]     loss: 0.22848
# [epoch:5  iter:11000  elapsed_time:6433 secs]     loss: 0.16913
# [epoch:5  iter:11200  elapsed_time:6453 secs]     loss: 0.18117
# [epoch:5  iter:11400  elapsed_time:6471 secs]     loss: 0.14693
# [epoch:5  iter:11600  elapsed_time:6489 secs]     loss: 0.05556
# [epoch:5  iter:11800  elapsed_time:6507 secs]     loss: 0.18382
# [epoch:5  iter:12000  elapsed_time:6525 secs]     loss: 0.10777
# [epoch:5  iter:12200  elapsed_time:6544 secs]     loss: 0.19817
# [epoch:5  iter:12400  elapsed_time:6564 secs]     loss: 0.11759
# [epoch:5  iter:12600  elapsed_time:6582 secs]     loss: 0.12926
# [epoch:5  iter:12800  elapsed_time:6602 secs]     loss: 0.04087
# [epoch:5  iter:13000  elapsed_time:6623 secs]     loss: 0.13721
# [epoch:5  iter:13200  elapsed_time:6642 secs]     loss: 0.10417
# [epoch:5  iter:13400  elapsed_time:6659 secs]     loss: 0.18332
# [epoch:5  iter:13600  elapsed_time:6679 secs]     loss: 0.04370
# [epoch:5  iter:13800  elapsed_time:6699 secs]     loss: 0.17679
# [epoch:5  iter:14000  elapsed_time:6716 secs]     loss: 0.11836
# [epoch:5  iter:14200  elapsed_time:6735 secs]     loss: 0.09581
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Total Training Time: 1197645.886385218
#
# Finished Training

# %%
def run_code_for_testing_text_classification_with_GRU_word2vec(net, test_dataloader):
    classification_accuracy = 0.0
    negative_total = 0
    positive_total = 0
    confusion_matrix = torch.zeros(2,2)
    net = net.to(device)
    with torch.no_grad():
        for i, data in enumerate(test_dataloader):
            review_tensor,category,sentiment = data['review'], data['category'], data['sentiment']
            review_tensor = review_tensor.to(device)
            category = category.to(device)
            sentiment = sentiment.to(device)
            hidden = net.init_hidden()
            for k in range(review_tensor.shape[1]):
                output, hidden = net(torch.unsqueeze(torch.unsqueeze(review_tensor[0,k],0),0), hidden)
            predicted_idx = torch.argmax(output).item()
            gt_idx = torch.argmax(sentiment).item()
            if i % 100 == 99:
                print("   [i=%d]    predicted_label=%d       gt_label=%d" % (i+1, predicted_idx,gt_idx))
            if predicted_idx == gt_idx:
                classification_accuracy += 1
            if gt_idx == 0: 
                negative_total += 1
            elif gt_idx == 1:
                positive_total += 1
            confusion_matrix[gt_idx,predicted_idx] += 1
    print("\nOverall classification accuracy: %0.2f%%" %  (float(classification_accuracy) * 100 /float(i)))
    out_percent = np.zeros((2,2), dtype='float')
    out_percent[0,0] = "%.3f" % (100 * confusion_matrix[0,0] / float(negative_total))
    out_percent[0,1] = "%.3f" % (100 * confusion_matrix[0,1] / float(negative_total))
    out_percent[1,0] = "%.3f" % (100 * confusion_matrix[1,0] / float(positive_total))
    out_percent[1,1] = "%.3f" % (100 * confusion_matrix[1,1] / float(positive_total))
    print("\n\nNumber of positive reviews tested: %d" % positive_total)
    print("\n\nNumber of negative reviews tested: %d" % negative_total)
    print("\n\nDisplaying the confusion matrix:\n")
    out_str = "                      "
    out_str +=  "%18s    %18s" % ('predicted negative', 'predicted positive')
    print(out_str + "\n")
    for i,label in enumerate(['true negative', 'true positive']):
        out_str = "%12s:  " % label
        for j in range(2):
            out_str +=  "%18s%%" % out_percent[i,j]
        print(out_str)

# %%
dataroot = './'
dataset_archive_test = "data/sentiment_dataset_test_400.tar.gz"
path_to_saved_embeddings = './'
batch_size = 1
path_saved_model = './net.pth'
device = 'cuda'


dataserver_test = SentimentAnalysisDataLoader(dataroot, train_or_test = 'test',dataset_file = dataset_archive_test,
                                 path_to_saved_embeddings = path_to_saved_embeddings)
test_dataloader = torch.utils.data.DataLoader(dataserver_test,
                        batch_size=batch_size,shuffle=False, num_workers=2)
    
model = torch.load(path_saved_model)
run_code_for_testing_text_classification_with_GRU_word2vec(model,test_dataloader)
# Out:
#    [i=100]    predicted_label=1       gt_label=1
#    [i=200]    predicted_label=1       gt_label=0
#    [i=300]    predicted_label=0       gt_label=0
#    [i=400]    predicted_label=1       gt_label=1
#    [i=500]    predicted_label=1       gt_label=1
#    [i=600]    predicted_label=1       gt_label=1
#    [i=700]    predicted_label=1       gt_label=1
#    [i=800]    predicted_label=1       gt_label=1
#    [i=900]    predicted_label=1       gt_label=1
#    [i=1000]    predicted_label=1       gt_label=1
#    [i=1100]    predicted_label=1       gt_label=1
#    [i=1200]    predicted_label=1       gt_label=0
#    [i=1300]    predicted_label=1       gt_label=1
#    [i=1400]    predicted_label=1       gt_label=1
#    [i=1500]    predicted_label=0       gt_label=0
#    [i=1600]    predicted_label=0       gt_label=0
#    [i=1700]    predicted_label=1       gt_label=1
#    [i=1800]    predicted_label=1       gt_label=1
#    [i=1900]    predicted_label=1       gt_label=1
#    [i=2000]    predicted_label=0       gt_label=0
#    [i=2100]    predicted_label=1       gt_label=1
#    [i=2200]    predicted_label=1       gt_label=0
#    [i=2300]    predicted_label=0       gt_label=0
#    [i=2400]    predicted_label=1       gt_label=1
#    [i=2500]    predicted_label=1       gt_label=1
#    [i=2600]    predicted_label=0       gt_label=1
#    [i=2700]    predicted_label=0       gt_label=0
#    [i=2800]    predicted_label=0       gt_label=0
#    [i=2900]    predicted_label=1       gt_label=1
#    [i=3000]    predicted_label=0       gt_label=0
#    [i=3100]    predicted_label=0       gt_label=0
#    [i=3200]    predicted_label=1       gt_label=0
#    [i=3300]    predicted_label=0       gt_label=0
#    [i=3400]    predicted_label=1       gt_label=0
#    [i=3500]    predicted_label=1       gt_label=1
#
# Overall classification accuracy: 87.48%
#
#
# Number of positive reviews tested: 1911
#
#
# Number of negative reviews tested: 1652
#
#
# Displaying the confusion matrix:
#
#                       predicted negative    predicted positive
#
# true negative:              90.012%             9.988%
# true positive:              14.757%            85.243%
